# %%
# import the necessary libraries
import numpy as np
import pandas as pd
pd.set_option('display.float_format', '{:.0f}'.format) # To format the float numbers so they don't show exponential values.

# %%
# for visuals
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load and read data file
'''inside the quotation is a filepath of the data file'''
df = pd.read_csv(r'C:\Users\yejie\OneDrive\Desktop\Quantum Analytics (Pyton)\Unicorn_Companies.csv') 
df['Date Joined'] = pd.to_datetime(df['Date Joined'])
df
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %%
# to find data type
df.dtypes
# Out:
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country                     object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# dtype: object

# %%
# check the first 5 rows
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
# check the last 5 rows
df.tail()
# Out:
#           Company Valuation Date Joined                         Industry  \
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#             City         Country      Continent  Year Founded Funding  \
# 1069    Shanghai           China           Asia          2012   $379M
# 1070     Beijing           China           Asia          2015   $990M
# 1071   Chongqing           China           Asia          2018    $80M
# 1072      London  United Kingdom         Europe          2005   $792M
# 1073  Long Beach   United States  North America          2014   $620M
#
#                                        Select Investors
# ...

# %% [markdown]
# ### Data Inspection and Manipulation

# %%
# view the shape of the data
df.shape
# Out:
# (1074, 10)

# %%
# view info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 84.0+ KB

# %%
# view columns
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors'],
#       dtype='object')

# %%
# view the summary statistics of the dataset
df.describe()
# Out:
#        Year Founded
# count          1074
# mean           2013
# std               6
# min            1919
# 25%            2011
# 50%            2014
# 75%            2016
# max            2021

# %%
# check for missing values
df.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year Founded         0
# Funding              0
# Select Investors     1
# dtype: int64

# %%
# visualise the missing values
plt.figure(figsize = (10,5))
plt.title('visualizing missing values')
sns.heatmap(df.isnull(), cbar = True, cmap = 'magma')
plt.show()

# %%
# city with missing records
df[df.City.isnull()]
# Out:
#                          Company Valuation Date Joined  \
# 12                           FTX      $32B  2021-07-20
# 170                    HyalRoute       $4B  2020-05-26
# 242                       Moglix       $3B  2021-05-17
# 251                         Trax       $3B  2019-07-22
# 325                  Amber Group       $3B  2021-06-21
# 382                    Ninja Van       $2B  2021-09-27
# 541   Advance Intelligence Group       $2B  2021-09-23
# 811                    Carousell       $1B  2021-09-15
# 848                   Matrixport       $1B  2021-06-01
# 880                     bolttech       $1B  2021-07-01
# 889                        Carro       $1B  2021-06-14
# 893                        Cider       $1B  2021-09-02
# 980                         NIUM       $1B  2021-07-13
# 986                          ONE       $1B  2021-12-08
# 994                      PatSnap       $1B  2021-03-16
# 1061                       WeLab       $1B  2017-11-08
#
# ...

# %%
# record with missing Select Investors
df = df.rename(columns={'Select Investors':'Select_Investors'})

df[df.Select_Investors.isnull()]
# Out:
#               Company Valuation Date Joined                     Industry  \
# 629  LinkSure Network       $1B  2015-01-01  Mobile & telecommunications
#
#          City Country Continent  Year Founded Funding Select_Investors
# 629  Shanghai   China      Asia          2013    $52M              NaN

# %%
# we found that the NaN was now represented as <NA>
df.City.value_counts()
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
#                 ...
# Santa Barbara      1
# Altrincham         1
# Northbrook         1
# Cincinnati         1
# Milpitas           1
# Name: City, Length: 256, dtype: int64

# %%
df.dtypes
# Out:
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country                     object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select_Investors            object
# dtype: object

# %%
# we found that the NaN was now represented as <NA>
df['City'].fillna('Unidentified', inplace=True)
df['Select_Investors'].fillna('Unidentified', inplace=True)

# %%
df.isna().sum()
# Out:
# Company             0
# Valuation           0
# Date Joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year Founded        0
# Funding             0
# Select_Investors    0
# dtype: int64

# %%
df[df.Select_Investors == 'Unidentified']
# Out:
#               Company Valuation Date Joined                     Industry  \
# 629  LinkSure Network       $1B  2015-01-01  Mobile & telecommunications
#
#          City Country Continent  Year Founded Funding Select_Investors
# 629  Shanghai   China      Asia          2013    $52M     Unidentified

# %%
df.sample(5)
# Out:
#          Company Valuation Date Joined                      Industry  \
# 1058         VTS       $1B  2019-05-07  Internet software & services
# 304        Cedar       $3B  2021-03-09                       Fintech
# 335      FlixBus       $3B  2019-07-18         Auto & transportation
# 819           G2       $1B  2021-06-22  Internet software & services
# 589   Redis Labs       $2B  2020-08-25   Data management & analytics
#
#                City        Country      Continent  Year Founded Funding  \
# 1058       New York  United States  North America          2012   $187M
# 304        New York  United States  North America          2016   $326M
# 335          Munich        Germany         Europe          2013     $1B
# 819         Chicago  United States  North America          2012   $258M
# 589   Mountain View  United States  North America          2011   $356M
#
#                                        Select_Investors
# 1058  Trinity Ventures, Fifth Wall Ventures, OpenVie...
# ...

# %%
''' pd.set_option('display.float_format', '{:.0f}'.format) # To format the float numbers to they don't show exponential values.
code to change 1e6 to 1000000
'''
df['Valuation'] = df['Valuation'].str.replace('$', '').str.replace('B', 'e9').str.replace('M', 'e6').astype(float)
# Out:
# C:\Users\yejie\AppData\Local\Temp\ipykernel_5156\4027372414.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Valuation'] = df['Valuation'].str.replace('$', '').str.replace('B', 'e9').str.replace('M', 'e6').astype(float)

# %%
# check the number of unknown in funding
df[df.Funding == 'Unknown']
# Out:
#               Company  Valuation Date Joined  \
# 215            SSENSE 4000000000  2021-06-08
# 424           Uplight 2000000000  2021-03-03
# 567               ISN 2000000000  2020-12-17
# 639        SITECH DEV 1000000000  2019-05-16
# 651          Xiaobing 1000000000  2021-07-12
# 717            Veepee 1000000000  2007-07-02
# 733         DistroKid 1000000000  2021-08-16
# 866          Assembly 1000000000  2021-09-21
# 890      Carson Group 1000000000  2021-07-14
# 945   Iodine Software 1000000000  2021-12-01
# 947      Kendra Scott 1000000000  2016-12-21
# 1002           Poizon 1000000000  2019-04-29
#
#                                  Industry                   City  \
# 215       E-commerce & direct-to-consumer               Montreal
# 424                                 Other                Boulder
# 567   Supply chain, logistics, & delivery                 Dallas
# 639                                 Other                Guiyang
# ...

# %%
# replace the unknown in funding with nan
df['Funding'].replace('Unknown', np.nan, inplace=True)

# %%
# replace the dollar sign, B to represent billion and M to represent million
df['Funding'] = df['Funding'].str.replace('$', '').str.replace('B', 'e9').str.replace('M', 'e6').astype(float)
df.head()
# Out:
# C:\Users\yejie\AppData\Local\Temp\ipykernel_5156\3440324324.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Funding'] = df['Funding'].str.replace('$', '').str.replace('B', 'e9').str.replace('M', 'e6').astype(float)
#      Company    Valuation Date Joined                         Industry  \
# 0  Bytedance 180000000000  2017-04-07          Artificial intelligence
# 1     SpaceX 100000000000  2012-12-01                            Other
# 2      SHEIN 100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe  95000000000  2014-01-23                          Fintech
# 4     Klarna  46000000000  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded    Funding  \
# 0        Beijing          China           Asia          2012 8000000000
# ...

# %%
# fill the nan with the median value 
median = df['Funding'].median()
df['Funding'].fillna(median, inplace=True)

# %%
df.isnull().sum()
# Out:
# Company             0
# Valuation           0
# Date Joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year Founded        0
# Funding             0
# Select_Investors    0
# dtype: int64

# %%
df.describe().T
# Out:
#               count       mean        std        min        25%        50%  \
# Valuation      1074 3455307263 8547022216 1000000000 1000000000 2000000000
# Year Founded   1074       2013          6       1919       2011       2014
# Funding        1074  555176909  805831410          0  224000000  370000000
#
#                     75%          max
# Valuation    3000000000 180000000000
# Year Founded       2016         2021
# Funding       603000000  14000000000

# %%
# Extract 'Year Joined' from 'Date Joined'
df['Year Joined'] = df['Date Joined'].dt.year

# Get the age of the company when it joined the list
df['Age When Joined'] = df['Year Joined'] - df['Year Founded']

df.head()
# Out:
#      Company    Valuation Date Joined                         Industry  \
# 0  Bytedance 180000000000  2017-04-07          Artificial intelligence
# 1     SpaceX 100000000000  2012-12-01                            Other
# 2      SHEIN 100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe  95000000000  2014-01-23                          Fintech
# 4     Klarna  46000000000  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded    Funding  \
# 0        Beijing          China           Asia          2012 8000000000
# 1      Hawthorne  United States  North America          2002 7000000000
# 2       Shenzhen          China           Asia          2008 2000000000
# 3  San Francisco  United States  North America          2010 2000000000
# 4      Stockholm         Sweden         Europe          2005 4000000000
#
#                                     Select_Investors  Year Joined  \
# ...

# %%
df['ROI %']= (df['Valuation']/df['Funding']) * 100
df.head()
# Out:
#      Company    Valuation Date Joined                         Industry  \
# 0  Bytedance 180000000000  2017-04-07          Artificial intelligence
# 1     SpaceX 100000000000  2012-12-01                            Other
# 2      SHEIN 100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe  95000000000  2014-01-23                          Fintech
# 4     Klarna  46000000000  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded    Funding  \
# 0        Beijing          China           Asia          2012 8000000000
# 1      Hawthorne  United States  North America          2002 7000000000
# 2       Shenzhen          China           Asia          2008 2000000000
# 3  San Francisco  United States  North America          2010 2000000000
# 4      Stockholm         Sweden         Europe          2005 4000000000
#
#                                     Select_Investors  Year Joined  \
# ...

# %%
df.sort_values(by='ROI %', ascending=False).head()
# Out:
#                   Company  Valuation Date Joined  \
# 189  Otto Bock HealthCare 4000000000  2017-06-24
# 239                Zapier 4000000000  2021-01-14
# 61                 Dunamu 9000000000  2021-07-22
# 792             Workhuman 1000000000  2020-06-23
# 361                  CFGI 2000000000  2021-09-15
#
#                          Industry        City        Country      Continent  \
# 189                        Health  Duderstadt        Germany         Europe
# 239  Internet software & services   Sunnyvale  United States  North America
# 61                        Fintech       Seoul    South Korea           Asia
# 792  Internet software & services      Dublin        Ireland         Europe
# 361                       Fintech      Boston  United States  North America
#
#      Year Founded  Funding                                   Select_Investors  \
# 189          1919        0                                       EQT Partners
# ...

# %%
# count the number of infinite values
number_inf = df[df == np.inf].count()
number_inf
# Out:
# Company             0
# Valuation           0
# Date Joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year Founded        0
# Funding             0
# Select_Investors    0
# Year Joined         0
# Age When Joined     0
# ROI %               1
# dtype: int64

# %%
df[np.isinf(df['ROI %'])]
# Out:
#                   Company  Valuation Date Joined Industry        City  \
# 189  Otto Bock HealthCare 4000000000  2017-06-24   Health  Duderstadt
#
#      Country Continent  Year Founded  Funding Select_Investors  Year Joined  \
# 189  Germany    Europe          1919        0     EQT Partners         2017
#
#      Age When Joined  ROI %
# 189               98    inf

# %%
top_5 = df.sort_values('ROI %',ascending=False).head(5)
top_5
# Out:
#                   Company  Valuation Date Joined  \
# 189  Otto Bock HealthCare 4000000000  2017-06-24
# 239                Zapier 4000000000  2021-01-14
# 61                 Dunamu 9000000000  2021-07-22
# 792             Workhuman 1000000000  2020-06-23
# 361                  CFGI 2000000000  2021-09-15
#
#                          Industry        City        Country      Continent  \
# 189                        Health  Duderstadt        Germany         Europe
# 239  Internet software & services   Sunnyvale  United States  North America
# 61                        Fintech       Seoul    South Korea           Asia
# 792  Internet software & services      Dublin        Ireland         Europe
# 361                       Fintech      Boston  United States  North America
#
#      Year Founded  Funding                                   Select_Investors  \
# 189          1919        0                                       EQT Partners
# ...

# %%
plt.figure(figsize=(8,5))
sns.barplot(data= top_5, x="Company", y='ROI %')
plt.title('Top 5 companies by ROI')
plt.ylabel('ROI')
plt.xlabel('Company')
plt.xticks(rotation=90)
plt.show()

# %%
df['ROI %'].sort_values(ascending=False).head(5)
# Out:
# 189      inf
# 239   400000
# 61     12676
# 792    11111
# 361    10526
# Name: ROI %, dtype: float64

# %%
# 5 top companies  with biggest return on investment
# Top 5 Company by using ROI
# top5_company = df['Company'].groupby(df['ROI%']).sum().head()
# top5_Company

# %%
# How long it takes to become a unicorn

sns.boxplot(df['Age When Joined'])
plt.ylabel('Age')
plt.title('Age distibution until Unicorn status')
# Out:
# Text(0.5, 1.0, 'Age distibution until Unicorn status')

# %%
df.head()
# Out:
#      Company    Valuation Date Joined                         Industry  \
# 0  Bytedance 180000000000  2017-04-07          Artificial intelligence
# 1     SpaceX 100000000000  2012-12-01                            Other
# 2      SHEIN 100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe  95000000000  2014-01-23                          Fintech
# 4     Klarna  46000000000  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded    Funding  \
# 0        Beijing          China           Asia          2012 8000000000
# 1      Hawthorne  United States  North America          2002 7000000000
# 2       Shenzhen          China           Asia          2008 2000000000
# 3  San Francisco  United States  North America          2010 2000000000
# 4      Stockholm         Sweden         Europe          2005 4000000000
#
#                                     Select_Investors  Year Joined  \
# ...

# %%
# Top 5 Countries with the most unicorns
df.Country.value_counts().head()
# Out:
# United States     562
# China             173
# India              65
# United Kingdom     43
# Germany            26
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(8,5))
df.Country.value_counts().head().plot(kind='bar')
plt.title('Top 5 Countries with most Unicorn')
plt.ylabel('Number of unicorns')
plt.xlabel('Countries')
plt.xticks(rotation=90)
plt.show()

# %%
# Top 5 Cities that are industrial hubs
df.City.value_counts().head()
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
# Name: City, dtype: int64

# %%
df.Select_Investors.value_counts().head(20)
# Out:
# Sequoia Capital                                                                                3
# Speedinvest, Valar Ventures, Uniqa Ventures                                                    2
# General Atlantic                                                                               2
# Sequoia Capital China, Qiming Venture Partners, Tencent Holdings                               2
# Global Founders Capital, Shea Ventures, Greycroft                                              2
# Greylock Partners, Google Ventures, BlackRock                                                  2
# SoftBank Group                                                                                 2
# Insight Partners, Sequoia Capital, Index Ventures                                              2
# Undisclosed                                                                                    2
# Qualcomm Ventures, Accel, Canaan Partners                                                      2
# ...

# %%
df2 = df.copy() # to make a copy of the original dataset

# convert the investors column from a string to a list
df2.Select_Investors = df.Select_Investors.str.split(', ')

# %%
df2.head()
# Out:
#      Company    Valuation Date Joined                         Industry  \
# 0  Bytedance 180000000000  2017-04-07          Artificial intelligence
# 1     SpaceX 100000000000  2012-12-01                            Other
# 2      SHEIN 100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe  95000000000  2014-01-23                          Fintech
# 4     Klarna  46000000000  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded    Funding  \
# 0        Beijing          China           Asia          2012 8000000000
# 1      Hawthorne  United States  North America          2002 7000000000
# 2       Shenzhen          China           Asia          2008 2000000000
# 3  San Francisco  United States  North America          2010 2000000000
# 4      Stockholm         Sweden         Europe          2005 4000000000
#
#                                     Select_Investors  Year Joined  \
# ...

# %%
# count the number of investors in each list
top_investors = df2.Select_Investors.explode().value_counts().head(10)
top_investors
# Out:
# Accel                          60
# Tiger Global Management        53
# Andreessen Horowitz            53
# Sequoia Capital China          48
# Insight Partners               47
# Sequoia Capital                47
# Lightspeed Venture Partners    34
# SoftBank Group                 34
# General Catalyst               33
# Index Ventures                 32
# Name: Select_Investors, dtype: int64

# %%
plt.figure(figsize=(8,5))
top_investors.plot(kind='bar')
plt.title('Top 10 Unicorn Investors')
plt.ylabel('Number of unicorns')
plt.xlabel('investment company')
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of industries
industry_counts = df['Industry'].value_counts()
print(industry_counts)
# Out:
# Fintech                                224
# Internet software & services           205
# E-commerce & direct-to-consumer        111
# Health                                  74
# Artificial intelligence                 73
# Other                                   58
# Supply chain, logistics, & delivery     57
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             38
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Artificial Intelligence                 11
# Name: Industry, dtype: int64

# %%
# Merge industries Artificial intelligence and Artificial Intelligence
df.loc[df.Industry== 'Artificial intelligence', 'Industry']  = 'Artificial Intelligence'
industry_counts = df['Industry'].value_counts()
print(industry_counts)
# Out:
# Fintech                                224
# Internet software & services           205
# E-commerce & direct-to-consumer        111
# Artificial Intelligence                 84
# Health                                  74
# Other                                   58
# Supply chain, logistics, & delivery     57
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             38
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Name: Industry, dtype: int64

# %%
# Diversification of Investment - Portfolio by Industry
plt.figure(figsize=(10,6))
df['Industry'].value_counts().plot(kind='bar')
plt.title('Number of Companies by Industry')
plt.xlabel('Industry')
plt.ylabel('Number of Company')
plt.show()

# %%
# Visualization of industries vs Valuation
plt.figure(figsize=(10,6))
df.groupby('Industry')['Valuation'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title('Average Valuation by Industry')
plt.xlabel('Industry')
plt.ylabel('Valuation in Billions')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='City', order=df.City.value_counts().iloc[:10].index)
plt.xlabel('City')
plt.ylabel('Number of Unicorns')
plt.title('Geographic Distribution of Unicorns - Top 10 Cities')
plt.xticks(rotation=45)
plt.show()

# %%
# Average funding by industries

plt.figure(figsize=(10,6))
df.groupby('Industry')['Funding'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title('Average Funding by Industry')
plt.ylabel('Funding in Billions')
plt.show()

# %%
# Distribution of unicorns by continent
continent_counts = df['Continent'].value_counts()
print(continent_counts)
# Out:
# North America    589
# Asia             310
# Europe           143
# South America     21
# Oceania            8
# Africa             3
# Name: Continent, dtype: int64

# %%
plt.figure(figsize=(10,6))
df['Continent'].value_counts().plot(kind='bar')
plt.title('Number of Companies by Continent')
plt.xlabel('Continent')
plt.ylabel('Number of Unicorns')
plt.show()

# %%
# Relationship between valuation and funding
plt.figure(figsize=(10,6))
sns.scatterplot(x='Funding', y='Valuation', data=df)
plt.title('Relationship Between Funding and Valuation')
plt.xlabel('Funding in Billions')
plt.ylabel('Valuation in Billions')
plt.show()

# %%
# Time Trend of Company Valuations,'''it was observed below that many company joined the unicorn in 2011##'''
plt.figure(figsize=(10,6))
df.groupby('Year Joined')['Valuation'].mean().plot(kind='line')
plt.title('Average Valuation Over Years')
plt.ylabel('Valuation in Billions')
plt.show()

# %%
# Year Founded distribution.
plt.figure(figsize=(10, 6))
plt.hist(df['Year Founded'], bins=50)
plt.xlabel('Year Founded')
plt.ylabel('Number of Unicorn Companies')
plt.title('Distribution of Year Founded')
plt.show()

# %%
# filtering for AI companies 
df[df['Industry'] == 'Artificial Intelligence']
# Out:
#           Company    Valuation Date Joined                 Industry  \
# 0       Bytedance 180000000000  2017-04-07  Artificial Intelligence
# 29        Argo AI  12000000000  2019-07-12  Artificial Intelligence
# 31          Faire  12000000000  2019-10-30  Artificial Intelligence
# 63        Pony.ai   9000000000  2018-07-11  Artificial Intelligence
# 94       Scale AI   7000000000  2019-08-05  Artificial Intelligence
# ...           ...          ...         ...                      ...
# 1032   SoundHound   1000000000  2018-05-03  Artificial Intelligence
# 1034     Standard   1000000000  2021-02-17  Artificial Intelligence
# 1039  TensTorrent   1000000000  2021-05-05  Artificial Intelligence
# 1046    Tractable   1000000000  2021-06-16  Artificial Intelligence
# 1050        Unico   1000000000  2021-08-03  Artificial Intelligence
#
#                City         Country      Continent  Year Founded    Funding  \
# ...

# %%
df[df['Industry'] == 'Artificial Intelligence']
# Out:
#           Company    Valuation Date Joined                 Industry  \
# 0       Bytedance 180000000000  2017-04-07  Artificial Intelligence
# 29        Argo AI  12000000000  2019-07-12  Artificial Intelligence
# 31          Faire  12000000000  2019-10-30  Artificial Intelligence
# 63        Pony.ai   9000000000  2018-07-11  Artificial Intelligence
# 94       Scale AI   7000000000  2019-08-05  Artificial Intelligence
# ...           ...          ...         ...                      ...
# 1032   SoundHound   1000000000  2018-05-03  Artificial Intelligence
# 1034     Standard   1000000000  2021-02-17  Artificial Intelligence
# 1039  TensTorrent   1000000000  2021-05-05  Artificial Intelligence
# 1046    Tractable   1000000000  2021-06-16  Artificial Intelligence
# 1050        Unico   1000000000  2021-08-03  Artificial Intelligence
#
#                City         Country      Continent  Year Founded    Funding  \
# ...

# %%
# To find the Fintech in Africa
df[(df['Industry'] == 'Fintech') & (df['Continent'] == 'Africa')]
# Out:
#     Company  Valuation Date Joined Industry   City  Country Continent  \
# 484    Wave 2000000000  2021-09-07  Fintech  Dakar  Senegal    Africa
# 585    Opay 2000000000  2021-08-23  Fintech  Lagos  Nigeria    Africa
#
#      Year Founded   Funding  \
# 484          2018 200000000
# 585          2018 570000000
#
#                                       Select_Investors  Year Joined  \
# 484            Stripe, Founders Fund, Partech Partners         2021
# 585  Sequoia Capital China, Source Code Capital, Re...         2021
#
#      Age When Joined  ROI %
# 484                3   1000
# 585                3    351

# %%
# Artificial Intelligence in Africa
df[(df['Industry'] == 'Artificial Intelligence') & (df['Continent'] == 'Africa')]
# Out:
# Empty DataFrame
# Columns: [Company, Valuation, Date Joined, Industry, City, Country, Continent, Year Founded, Funding, Select_Investors, Year Joined, Age When Joined, ROI %]
# Index: []

# %% [markdown]
# ### Observation
# Focus on High Growth Industries: Certain industries like Artificial Intelligence and E-commerce & direct-to-consumer had been seen to harbor a high valuation for Unicorn companies. Thus, investors should consider focusing on these high-growth potential industries when making investment decisions.It was also observed that continent like africa has no artificial intelligence but Fintech
#
# Geographical Diversification: The data shows that most of the Unicorn companies are based in countries like the United States and China, and cities like San Francisco and Beijing. Investors can diversify their portfolios by also investing in Unicorn companies in other promising locations.it was also observe
#
# Age of Company Consideration: The age of the companies when they joined the Unicorn list varies. Thus, investors should not rule out younger or older companies when considering investment opportunities. Each comes with its own risks and opportunities: younger companies might offer high growth and innovation, while older companies might provide stability and steady growth.
#
# Funding and Valuation Correlation: No relationship between funding and valuation was observed. While higher funding doesn't guarantee a higher valuation, it can be one of the factors to consider. Companies that have attracted more funding might have done so because they have convincing business models or growth potential.
#
# Portfolio Diversification by Industry: Just as with geographical diversification, investors should also diversify their portfolios across different industries. This could mitigate industry-specific risks and increase potential for higher returns.
#
# Return on Investment(ROI) : Companies like Otto Bock Healthcare and Zapier were found to have the the greatest return on investment compared to others
